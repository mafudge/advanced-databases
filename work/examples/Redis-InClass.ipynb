# %%
import requests
url = "http://openinsider.com/screener?s=MSFT"

response = requests.get(url)
response.text

# %%
# !pip install redis lxml
# Out:
# Requirement already satisfied: redis in /opt/conda/lib/python3.9/site-packages (4.5.3)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.9/site-packages (4.9.2)
# Requirement already satisfied: async-timeout>=4.0.2 in /opt/conda/lib/python3.9/site-packages (from redis) (4.0.2)

# %%
import redis
connection = redis.Redis(host="redis", decode_responses=True)

# %%
result = connection.hgetall("user:1")

# %%
result
# Out:
# {'username': 'mike',
#  'password': 'mike',
#  'auth': '42d364b4efb8e98e103772fbad26e485'}

# %%
data = { 'username' : 'tony', 'food' : 'cheese', 'age' : 99} 
connection.hset("user:3", mapping=data)
# Out:
# 3

# %%
# Scrape from web do once...

stocks = ['AAPL', 'GOOG', 'MSFT']

for stock in stocks:
    key = f"ticker:{stock}"
    url = f"http://openinsider.com/screener?s={stock}"
    print(key, url)
    response = requests.get(url)
    page = response.text
    connection.set(key, page)
# Out:
# ticker:AAPL http://openinsider.com/screener?s=AAPL
# ticker:GOOG http://openinsider.com/screener?s=GOOG
# ticker:MSFT http://openinsider.com/screener?s=MSFT

# %%
connection.save()
# Out:
# True

# %%
import pandas as pd
import redis
from IPython.display import display
df = pd.DataFrame()
connection = redis.Redis(host="redis", decode_responses=True)
## get from redis
for key in connection.keys("ticker:*"):
    page = connection.get(key)
    tmp = pd.read_html(page)[11]
    df = df.append(tmp)
    #display(df)

# %%
df.to_csv(.....)
# Out:
#       X          Filing Date  Trade Date Ticker        Insider Name  \
# 0   NaN  2023-03-24 18:31:12  2023-03-22   AAPL  Williams Jeffrey E
# 1   NaN  2022-11-23 18:30:27  2022-11-22   AAPL         Kondo Chris
# 2   NaN  2022-11-01 18:30:34  2022-10-28   AAPL        Maestri Luca
# 3     D  2022-10-18 18:33:15  2022-10-17   AAPL     O'Brien Deirdre
# 4     D  2022-10-04 22:05:07  2022-10-03   AAPL     O'Brien Deirdre
# 5     D  2022-10-04 22:02:25  2022-10-03   AAPL  Adams Katherine L.
# 6     A  2022-08-22 18:43:18  2022-08-17   AAPL        Maestri Luca
# 7   NaN  2022-08-19 18:30:27  2022-08-17   AAPL        Maestri Luca
# 8   NaN  2022-08-05 18:30:49  2022-08-03   AAPL  Adams Katherine L.
# 9   NaN  2022-05-06 18:30:57  2022-05-04   AAPL  Adams Katherine L.
# 10    D  2022-04-19 18:31:54  2022-04-18   AAPL     O'Brien Deirdre
# 11    D  2022-04-05 18:33:35  2022-04-04   AAPL  Williams Jeffrey E
# 12    D  2022-04-05 18:32:41  2022-04-04   AAPL     O'Brien Deirdre
# 13  NaN  2022-02-07 18:30:37  2022-02-03   AAPL  Adams Katherine L.
# 14    D  2022-02-03 18:35:50  2022-02-01   AAPL   Levinson Arthur D
# 15  NaN  2021-11-16 18:30:25  2021-11-12   AAPL         Kondo Chris
# 16  NaN  2021-11-03 18:31:28  2021-11-01   AAPL  Adams Katherine L.
# 17  NaN  2021-10-21 18:30:48  2021-10-19   AAPL        Maestri Luca
# 18    D  2021-10-19 18:31:45  2021-10-18   AAPL     O'Brien Deirdre
# 19    D  2021-10-05 18:44:42  2021-10-04   AAPL  Williams Jeffrey E
# 20    D  2021-10-05 18:43:32  2021-10-04   AAPL     O'Brien Deirdre
# 21    D  2021-08-26 18:30:46  2021-08-25   AAPL      Cook Timothy D
# 22    D  2021-08-09 18:30:51  2021-08-06   AAPL     O'Brien Deirdre
# 23  NaN  2021-08-04 18:30:53  2021-08-02   AAPL  Adams Katherine L.
# 24  NaN  2021-05-05 18:31:41  2021-05-03   AAPL        Maestri Luca
# 25  NaN  2021-05-05 18:30:33  2021-05-03   AAPL  Adams Katherine L.
# 26    D  2021-04-19 18:31:41  2021-04-16   AAPL     O'Brien Deirdre
# 27    D  2021-04-05 18:36:12  2021-04-05   AAPL  Williams Jeffrey E
#
#                            Title   Trade Type    Price      Qty    Owned  \
# 0                            COO     S - Sale  $159.76  -187730   489816
# 1   Principal Accounting Officer     S - Sale  $148.72   -20200    31505
# 2                       SVP, CFO     S - Sale  $155.95  -176299   110673
# 3                            SVP  S - Sale+OE  $142.45    -8053   136290
# 4                            SVP  S - Sale+OE  $142.16  -176299   136290
# 5             SVP, GC, Secretary  S - Sale+OE  $141.41  -181139   427334
# 6                       SVP, CFO     S - Sale  $174.96   -96735   110673
# 7                       SVP, CFO     S - Sale  $174.96   -96735   110673
# 8             SVP, GC, Secretary     S - Sale  $164.77   -25000   427334
# 9             SVP, GC, Secretary     S - Sale  $161.72   -25000   452334
# 10                           SVP  S - Sale+OE  $164.91    -8000   136290
# 11                           COO  S - Sale+OE  $177.76  -105901   489662
# 12                           SVP  S - Sale+OE  $177.77   -29198   136290
# 13            SVP, GC, Secretary     S - Sale  $174.78   -25000   419715
# 14                           Dir  S - Sale+OE  $173.29    -1986  4588724
# 15  Principal Accounting Officer     S - Sale  $150.00    -9005    37197
# 16            SVP, GC, Secretary     S - Sale  $148.68   -25000   447993
# 17                      SVP, CFO     S - Sale  $148.62  -165829   110501
# 18                           SVP  S - Sale+OE  $146.35   -18247   136118
# 19                           COO  S - Sale+OE  $138.83  -165829   489490
# 20                           SVP  S - Sale+OE  $138.83   -89437   136118
# 21                           CEO  S - Sale+OE  $148.58 -2386440  3279726
# 22                           SVP  S - Sale+OE  $145.99   -14877   136118
# 23            SVP, GC, Secretary     S - Sale  $145.89   -17000   307164
# 24                      SVP, CFO     S - Sale  $132.81  -121072   110501
# 25            SVP, GC, Secretary     S - Sale  $132.80   -17000   328174
# 26                           SVP  S - Sale+OE  $134.01   -18216   136118
# 27                           COO  S - Sale+OE  $125.74  -133867   489490
#
#     ΔOwn          Value  1d  1w  1m  6m
# 0   -28%   -$29,991,745 NaN NaN NaN NaN
# 1   -39%    -$3,004,144 NaN NaN NaN NaN
# 2   -61%   -$27,493,275 NaN NaN NaN NaN
# 3    -6%    -$1,147,150 NaN NaN NaN NaN
# 4   -56%   -$25,062,882 NaN NaN NaN NaN
# 5   -30%   -$25,615,117 NaN NaN NaN NaN
# 6   -47%   -$16,924,259 NaN NaN NaN NaN
# 7   -47%   -$16,924,259 NaN NaN NaN NaN
# 8    -6%    -$4,119,155 NaN NaN NaN NaN
# 9    -5%    -$4,042,888 NaN NaN NaN NaN
# 10   -6%    -$1,319,305 NaN NaN NaN NaN
# 11  -18%   -$18,824,389 NaN NaN NaN NaN
# 12  -18%    -$5,190,427 NaN NaN NaN NaN
# 13   -6%    -$4,369,548 NaN NaN NaN NaN
# 14    0%      -$344,154 NaN NaN NaN NaN
# 15  -19%    -$1,350,750 NaN NaN NaN NaN
# 16   -5%    -$3,716,895 NaN NaN NaN NaN
# 17  -60%   -$24,645,506 NaN NaN NaN NaN
# 18  -12%    -$2,670,391 NaN NaN NaN NaN
# 19  -25%   -$23,022,040 NaN NaN NaN NaN
# 20  -40%   -$12,416,539 NaN NaN NaN NaN
# 21  -42%  -$354,568,479 NaN NaN NaN NaN
# 22  -10%    -$2,171,893 NaN NaN NaN NaN
# 23   -5%    -$2,480,048 NaN NaN NaN NaN
# 24  -52%   -$16,079,338 NaN NaN NaN NaN
# 25   -5%    -$2,257,631 NaN NaN NaN NaN
# 26  -12%    -$2,441,126 NaN NaN NaN NaN
# 27  -21%   -$16,832,437 NaN NaN NaN NaN

# %%
import pandas as pd

# %%
pd.read_html(page)[11]
# Out:
#       X          Filing Date  Trade Date Ticker             Insider Name  \
# 0   NaN  2023-03-02 18:12:08  2023-02-28   MSFT            Nadella Satya
# 1   NaN  2023-02-15 18:01:52  2023-02-13   MSFT  Capossela Christopher C
# 2   NaN  2023-02-13 18:07:31  2023-02-09   MSFT  Capossela Christopher C
# 3   NaN  2022-12-02 18:03:00  2022-12-01   MSFT           Althoff Judson
# 4   NaN  2022-09-13 18:02:38  2022-09-12   MSFT  Capossela Christopher C
# 5   NaN  2022-09-06 18:01:35  2022-09-02   MSFT                 Hood Amy
# 6   NaN  2022-09-02 18:03:58  2022-09-01   MSFT            Nadella Satya
# 7   NaN  2022-03-02 18:20:12  2022-03-01   MSFT            Nadella Satya
# 8   NaN  2022-02-09 18:16:05  2022-02-08   MSFT         Smith Bradford L
# 9     M  2022-02-01 18:15:17  2022-01-28   MSFT          Walmsley Emma N
# 10    D  2021-12-08 17:59:22  2021-12-07   MSFT                List Teri
# 11    M  2021-11-24 18:02:23  2021-11-22   MSFT            Nadella Satya
# 12  NaN  2021-11-03 18:13:01  2021-11-02   MSFT           Althoff Judson
# 13  NaN  2021-11-02 18:03:55  2021-11-01   MSFT         Smith Bradford L
# 14  NaN  2021-09-13 18:05:14  2021-09-10   MSFT         Hogan Kathleen T
# 15  NaN  2021-09-13 18:03:54  2021-09-10   MSFT  Capossela Christopher C
# 16  NaN  2021-09-03 18:05:42  2021-09-01   MSFT                 Hood Amy
# 17  NaN  2021-09-01 20:12:28  2021-09-01   MSFT            Nadella Satya
# 18    M  2021-05-14 18:09:23  2021-05-12   MSFT  Capossela Christopher C
# 19  NaN  2021-05-11 18:02:45  2021-05-10   MSFT         Smith Bradford L
# 20  NaN  2021-05-10 18:09:59  2021-05-07   MSFT  Capossela Christopher C
#
#                             Title    Trade Type    Price     Qty    Owned  \
# 0                             CEO      S - Sale  $248.88   -4767   788625
# 1                        EVP, CMO      S - Sale  $272.32   -1000   117666
# 2                        EVP, CMO      S - Sale  $269.38   -1000   118666
# 3   EVP, Chief Commercial Officer      S - Sale  $254.27  -24144   150047
# 4                        EVP, CMO      S - Sale  $266.25   -5000   112445
# 5                        EVP, CFO      S - Sale  $259.47  -75351   445859
# 6                             CEO      S - Sale  $257.71  -56999   799152
# 7                             CEO      S - Sale  $296.53   -7931   809645
# 8                Pres, Vice Chair      S - Sale  $304.64  -27860   622460
# 9                             Dir  P - Purchase  $303.26    3300     8818
# 10                            Dir   S - Sale+OE  $334.90   -1650     1654
# 11                            CEO      S - Sale  $340.26 -838584   830791
# 12  EVP, Chief Commercial Officer      S - Sale  $332.28  -54757   139586
# 13               Pres, Vice Chair      S - Sale  $328.60  -55000   654820
# 14                        EVP, HR      S - Sale  $298.68  -20000   183988
# 15                       EVP, CMO      S - Sale  $298.82  -10000    97023
# 16                       EVP, CFO      S - Sale  $303.08  -60000   463259
# 17                            CEO      S - Sale  $303.28  -75573  1669375
# 18                       EVP, CMO      S - Sale  $243.01   -3914    87897
# 19                           Pres      S - Sale  $250.27   -8000   646408
# 20                       EVP, CMO      S - Sale  $252.66   -6086    91811
#
#     ΔOwn          Value  1d  1w  1m  6m
# 0    -1%    -$1,186,411 NaN NaN NaN NaN
# 1    -1%      -$272,323 NaN NaN NaN NaN
# 2    -1%      -$269,380 NaN NaN NaN NaN
# 3   -14%    -$6,139,124 NaN NaN NaN NaN
# 4    -4%    -$1,331,251 NaN NaN NaN NaN
# 5   -14%   -$19,551,087 NaN NaN NaN NaN
# 6    -7%   -$14,689,028 NaN NaN NaN NaN
# 7    -1%    -$2,351,736 NaN NaN NaN NaN
# 8    -4%    -$8,487,170 NaN NaN NaN NaN
# 9   +60%    +$1,000,761 NaN NaN NaN NaN
# 10  -50%      -$552,578 NaN NaN NaN NaN
# 11  -50%  -$285,338,535 NaN NaN NaN NaN
# 12  -28%   -$18,194,837 NaN NaN NaN NaN
# 13   -8%   -$18,073,050 NaN NaN NaN NaN
# 14  -10%    -$5,973,540 NaN NaN NaN NaN
# 15   -9%    -$2,988,176 NaN NaN NaN NaN
# 16  -11%   -$18,184,980 NaN NaN NaN NaN
# 17   -4%   -$22,920,037 NaN NaN NaN NaN
# 18   -4%      -$951,151 NaN NaN NaN NaN
# 19   -1%    -$2,002,161 NaN NaN NaN NaN
# 20   -6%    -$1,537,711 NaN NaN NaN NaN
