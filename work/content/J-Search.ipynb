# %% [markdown]
# # Unit J
# # Search Database Model
#
# - Examples From Video Lecture

# %%
import pyspark
from pyspark.sql import SparkSession
# ELASTICSEARCH CONFIGURATION
elastic_host = "elasticsearch"
elastic_port = "9200"
spark = SparkSession.builder \
    .master("local") \
    .appName('jupyter-pyspark') \
    .config("spark.jars.packages","org.elasticsearch:elasticsearch-spark-30_2.12:8.17.0")\
    .config("spark.es.nodes", elastic_host) \
    .config("spark.es.port",elastic_port) \
    .getOrCreate()
sc = spark.sparkContext
sc.setLogLevel("ERROR")

# %% [markdown]
# ## Elasticsearch and Kibana
#
# ### Elasticsearch REST API
#
# - Use the HTTP protocol to add and query data in elasticsearch
# - open a terminal in Jupyter to run these from the Linux command prompt
#
# ```
# # add three documents
#
# curl -X POST "http://elasticsearch:9200/people/students" -H 'Content-Type: application/json' -d '{ "name" : "mike", "major" : "math", "gpa" : 3.4 }'
# curl -X POST "http://elasticsearch:9200/people/students" -H 'Content-Type: application/json' -d '{ "name" : "phil", "major" : "math", "gpa" : 3.2 }'
# curl -X POST "http://elasticsearch:9200/people/students" -H 'Content-Type: application/json' -d '{ "name" : "pete", "major" : "bio", "gpa" : 3.7 }'
#
# # Get a count of students (documents)
#
# curl -X GET "http://elasticsearch:9200/_cat/count/people"
#
# #  Find the math majors
#
# curl -X GET  "http://elasticsearch:9200/people/_search?pretty&q=major:math"
# ```
#
# - Type this into your web browser to find students with a GPA>3.3
# - NOTE: It's localhost now because we are not inside a docker container.
#
# ```
# http://localhost:9200/people/_search?pretty&q=gpa:[3.3 TO *]
# ```
#
# ### Kibana as a client of Elasticsearch
#
# - Kibana serves as an Elasticsearch client.
# - To view the people/students index, go to Management=> Stack Management=> Index Management
#     - Summary shows how many documents in the index
#     - Mappings shows the searchable fields discovered and their data types.
# - To use in Kibana, we must create a Kibana => Index Pattern
#     - There are text fiels like major and keyword fields like major.keyword for aggregations
#     - You can add custom fields by editing the value for example `deanslist` field as `emit( doc['gpa'].value > 3.3)`
# - Once your Index Pattern is created you can search : Analyticcs => Discover

# %% [markdown]
# ## Tweet Simulator
#
# - Genenrate some fake tweets in quazi-real time as a streaming data source
# - Each tweet is posted to elasticsearch and echoed to the console
# - This code will run until the user Stops the Notebook Cell or the Tweet limit is hit.

# %%
from simtweet import generateRandomTweet
import requests
from time import sleep
import random
import json
index = "tweets"
url = f"http://{elastic_host}:{elastic_port}/{index}"
headers = { "Content-Type" : "application/json" }
tweet_limit = 100
min_delay = 1
max_delay = 5

for i in range(tweet_limit):
    sleep(random.randint(min_delay, max_delay))
    tweet = generateRandomTweet()
    endpoint = f"{url}/_doc/{tweet['id']}"
    response = requests.post(endpoint, headers = headers, data = json.dumps(tweet))
    response.raise_for_status()
    print(f"curl -X POST {endpoint} -H 'Content-Type: application/json' \n\t-d '{json.dumps(tweet)}'")
# Out:
# curl -X POST http://elasticsearch:9200/tweets/_doc/1463065144848886549 -H 'Content-Type: application/json'
# 	-d '{"id": "1463065144848886549", "timestamp": [2023, 4, 10, 17, 51, 55, 0, 100, 0], "timestamp_format": "2023-04-10T17:51:55", "date": "2023-04-10", "time": "17:51:55", "user": "tanott", "lat": 29.38, "lon": -94.84, "text": "Hey fudgemart, why is your support so bad? #upset", "sentiment": "negative", "mentions": [], "hashtags": ["#upset"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4537573983336726708 -H 'Content-Type: application/json'
# 	-d '{"id": "4537573983336726708", "timestamp": [2023, 4, 10, 17, 52, 0, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:00", "date": "2023-04-10", "time": "17:52:00", "user": "afresco", "lat": 33.38, "lon": -96.79, "text": "Just got some electronics from #fudgemart. Awesome!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1677081450422603036 -H 'Content-Type: application/json'
# 	-d '{"id": "1677081450422603036", "timestamp": [2023, 4, 10, 17, 52, 2, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:02", "date": "2023-04-10", "time": "17:52:02", "user": "bdehatchett", "lat": 38.38, "lon": 87.76, "text": "Terrible. So Bad. #fudgemart", "sentiment": "negative", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4097311485126557558 -H 'Content-Type: application/json'
# 	-d '{"id": "4097311485126557558", "timestamp": [2023, 4, 10, 17, 52, 7, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:07", "date": "2023-04-10", "time": "17:52:07", "user": "jtyme", "lat": 40.39, "lon": -74.83, "text": "I make my first order from fudgemart last week.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4286072720820085606 -H 'Content-Type: application/json'
# 	-d '{"id": "4286072720820085606", "timestamp": [2023, 4, 10, 17, 52, 9, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:09", "date": "2023-04-10", "time": "17:52:09", "user": "sbeeches", "lat": 29.39, "lon": -99.68, "text": "How old are your clothes? Buy new ones at Fudgemart?", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2347555539283772337 -H 'Content-Type: application/json'
# 	-d '{"id": "2347555539283772337", "timestamp": [2023, 4, 10, 17, 52, 10, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:10", "date": "2023-04-10", "time": "17:52:10", "user": "bdehatchett", "lat": 38.38, "lon": 87.76, "text": "I'm really enjoying my new stuff from fudgemart", "sentiment": "positive", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2868157812935845195 -H 'Content-Type: application/json'
# 	-d '{"id": "2868157812935845195", "timestamp": [2023, 4, 10, 17, 52, 11, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:11", "date": "2023-04-10", "time": "17:52:11", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Hey, @fudgemart. You've got products with benefits!", "sentiment": "positive", "mentions": ["@fudgemart."], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3271657829929844097 -H 'Content-Type: application/json'
# 	-d '{"id": "3271657829929844097", "timestamp": [2023, 4, 10, 17, 52, 15, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:15", "date": "2023-04-10", "time": "17:52:15", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "#fudgemart customer service is predictable", "sentiment": "neutral", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1284985445129432418 -H 'Content-Type: application/json'
# 	-d '{"id": "1284985445129432418", "timestamp": [2023, 4, 10, 17, 52, 19, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:19", "date": "2023-04-10", "time": "17:52:19", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "Love or hate it. Fudgemart just is.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2853951466045925337 -H 'Content-Type: application/json'
# 	-d '{"id": "2853951466045925337", "timestamp": [2023, 4, 10, 17, 52, 21, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:21", "date": "2023-04-10", "time": "17:52:21", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "Hey #fudgemart, why is your support so bad? #angry", "sentiment": "negative", "mentions": [], "hashtags": ["#fudgemart,", "#angry"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3632363215716445033 -H 'Content-Type: application/json'
# 	-d '{"id": "3632363215716445033", "timestamp": [2023, 4, 10, 17, 52, 25, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:25", "date": "2023-04-10", "time": "17:52:25", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Glad I bought my books from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1802900795346655677 -H 'Content-Type: application/json'
# 	-d '{"id": "1802900795346655677", "timestamp": [2023, 4, 10, 17, 52, 28, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:28", "date": "2023-04-10", "time": "17:52:28", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Happy with my service from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/374281780006570988 -H 'Content-Type: application/json'
# 	-d '{"id": "374281780006570988", "timestamp": [2023, 4, 10, 17, 52, 33, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:33", "date": "2023-04-10", "time": "17:52:33", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "Why so horrible digital downloads? comeon, @fudgemart", "sentiment": "negative", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2872394562821451228 -H 'Content-Type: application/json'
# 	-d '{"id": "2872394562821451228", "timestamp": [2023, 4, 10, 17, 52, 35, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:35", "date": "2023-04-10", "time": "17:52:35", "user": "iquitten", "lat": 38.38, "lon": -95.51, "text": "Really enjoying my jewelry purchase from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2725425524235765931 -H 'Content-Type: application/json'
# 	-d '{"id": "2725425524235765931", "timestamp": [2023, 4, 10, 17, 52, 40, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:40", "date": "2023-04-10", "time": "17:52:40", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "How old are your clothes? Buy new ones at Fudgemart?", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2616240868389265323 -H 'Content-Type: application/json'
# 	-d '{"id": "2616240868389265323", "timestamp": [2023, 4, 10, 17, 52, 42, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:42", "date": "2023-04-10", "time": "17:52:42", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Really enjoying my jewelry purchase from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3281461137572516632 -H 'Content-Type: application/json'
# 	-d '{"id": "3281461137572516632", "timestamp": [2023, 4, 10, 17, 52, 43, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:43", "date": "2023-04-10", "time": "17:52:43", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "I make my first order from fudgemart last week.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1166100614744272514 -H 'Content-Type: application/json'
# 	-d '{"id": "1166100614744272514", "timestamp": [2023, 4, 10, 17, 52, 46, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:46", "date": "2023-04-10", "time": "17:52:46", "user": "afirenzergon", "lat": 41.38, "lon": -73.48, "text": "How many books can you read? Fudgemart has a nice selection.", "sentiment": "positive", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/63402287600210124 -H 'Content-Type: application/json'
# 	-d '{"id": "63402287600210124", "timestamp": [2023, 4, 10, 17, 52, 51, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:51", "date": "2023-04-10", "time": "17:52:51", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Happy with my service from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/738719819789430746 -H 'Content-Type: application/json'
# 	-d '{"id": "738719819789430746", "timestamp": [2023, 4, 10, 17, 52, 56, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:56", "date": "2023-04-10", "time": "17:52:56", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "Yo, @fudgemart", "sentiment": "neutral", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1238911950673468075 -H 'Content-Type: application/json'
# 	-d '{"id": "1238911950673468075", "timestamp": [2023, 4, 10, 17, 52, 58, 0, 100, 0], "timestamp_format": "2023-04-10T17:52:58", "date": "2023-04-10", "time": "17:52:58", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "Shopping on #fudgemart website is carefree.", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/139124756472921635 -H 'Content-Type: application/json'
# 	-d '{"id": "139124756472921635", "timestamp": [2023, 4, 10, 17, 53, 3, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:03", "date": "2023-04-10", "time": "17:53:03", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "The Electronics department at #fudgemart is amazing. So helpful!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3551114305376846044 -H 'Content-Type: application/json'
# 	-d '{"id": "3551114305376846044", "timestamp": [2023, 4, 10, 17, 53, 7, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:07", "date": "2023-04-10", "time": "17:53:07", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "The shipping process is flawed. Two weeks? Really? #fudgemart", "sentiment": "negative", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1871024615432985152 -H 'Content-Type: application/json'
# 	-d '{"id": "1871024615432985152", "timestamp": [2023, 4, 10, 17, 53, 10, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:10", "date": "2023-04-10", "time": "17:53:10", "user": "afresco", "lat": 33.38, "lon": -96.79, "text": "My shopping experience was delightful, @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4510028573466419863 -H 'Content-Type: application/json'
# 	-d '{"id": "4510028573466419863", "timestamp": [2023, 4, 10, 17, 53, 13, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:13", "date": "2023-04-10", "time": "17:53:13", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Glad I bought my books from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4204004214894298391 -H 'Content-Type: application/json'
# 	-d '{"id": "4204004214894298391", "timestamp": [2023, 4, 10, 17, 53, 14, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:14", "date": "2023-04-10", "time": "17:53:14", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "Fudgemart customer support is horrible. The worst.", "sentiment": "negative", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1532833773784814821 -H 'Content-Type: application/json'
# 	-d '{"id": "1532833773784814821", "timestamp": [2023, 4, 10, 17, 53, 16, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:16", "date": "2023-04-10", "time": "17:53:16", "user": "etasomthin", "lat": 43.38, "lon": -82.53, "text": "Fudgemart has a lot of Books available for purchase.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4041753783298210555 -H 'Content-Type: application/json'
# 	-d '{"id": "4041753783298210555", "timestamp": [2023, 4, 10, 17, 53, 20, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:20", "date": "2023-04-10", "time": "17:53:20", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "Very satisfying when your package arrives from #fudgemart", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/187142498492816311 -H 'Content-Type: application/json'
# 	-d '{"id": "187142498492816311", "timestamp": [2023, 4, 10, 17, 53, 22, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:22", "date": "2023-04-10", "time": "17:53:22", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "@fudgemart is better than @amazeen", "sentiment": "positive", "mentions": ["@fudgemart", "@amazeen"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4135285096591825316 -H 'Content-Type: application/json'
# 	-d '{"id": "4135285096591825316", "timestamp": [2023, 4, 10, 17, 53, 26, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:26", "date": "2023-04-10", "time": "17:53:26", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "Fudgemart has a lot of Books available for purchase.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2849986254278698758 -H 'Content-Type: application/json'
# 	-d '{"id": "2849986254278698758", "timestamp": [2023, 4, 10, 17, 53, 28, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:28", "date": "2023-04-10", "time": "17:53:28", "user": "tpani", "lat": 27.38, "lon": -82.64, "text": "You're the best @fudgemart! A+ shipping!", "sentiment": "positive", "mentions": ["@fudgemart!"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1838826703087109929 -H 'Content-Type: application/json'
# 	-d '{"id": "1838826703087109929", "timestamp": [2023, 4, 10, 17, 53, 30, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:30", "date": "2023-04-10", "time": "17:53:30", "user": "cpayne", "lat": 34.39, "lon": -83.74, "text": "I'm really enjoying my new stuff from fudgemart", "sentiment": "positive", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2690165230612189668 -H 'Content-Type: application/json'
# 	-d '{"id": "2690165230612189668", "timestamp": [2023, 4, 10, 17, 53, 33, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:33", "date": "2023-04-10", "time": "17:53:33", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Came home to a big smile my #fudgemart package arrived.", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1558909844007526286 -H 'Content-Type: application/json'
# 	-d '{"id": "1558909844007526286", "timestamp": [2023, 4, 10, 17, 53, 35, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:35", "date": "2023-04-10", "time": "17:53:35", "user": "gmoss", "lat": 41.38, "lon": -97.52, "text": "Shopping 4 books, electronics, and jewelry at #fudgemart.", "sentiment": "neutral", "mentions": [], "hashtags": ["#fudgemart."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2801108682153434548 -H 'Content-Type: application/json'
# 	-d '{"id": "2801108682153434548", "timestamp": [2023, 4, 10, 17, 53, 36, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:36", "date": "2023-04-10", "time": "17:53:36", "user": "afirenzergon", "lat": 41.38, "lon": -73.48, "text": "The Electronics department at #fudgemart is amazing. Great support!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/861548298886862262 -H 'Content-Type: application/json'
# 	-d '{"id": "861548298886862262", "timestamp": [2023, 4, 10, 17, 53, 37, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:37", "date": "2023-04-10", "time": "17:53:37", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Terrible. So Bad. #fudgemart", "sentiment": "negative", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1158742146512860105 -H 'Content-Type: application/json'
# 	-d '{"id": "1158742146512860105", "timestamp": [2023, 4, 10, 17, 53, 39, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:39", "date": "2023-04-10", "time": "17:53:39", "user": "iquitten", "lat": 38.38, "lon": -95.51, "text": "#fudgemart customer service is predictable", "sentiment": "neutral", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2864742094076766451 -H 'Content-Type: application/json'
# 	-d '{"id": "2864742094076766451", "timestamp": [2023, 4, 10, 17, 53, 44, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:44", "date": "2023-04-10", "time": "17:53:44", "user": "otyme", "lat": 30.39, "lon": -87.57, "text": "Glad I bought my jewelry from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/161297447004777796 -H 'Content-Type: application/json'
# 	-d '{"id": "161297447004777796", "timestamp": [2023, 4, 10, 17, 53, 48, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:48", "date": "2023-04-10", "time": "17:53:48", "user": "etasomthin", "lat": 43.38, "lon": -82.53, "text": "Shopping 4 books, electronics, and jewelry at #fudgemart.", "sentiment": "neutral", "mentions": [], "hashtags": ["#fudgemart."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4284942500502395006 -H 'Content-Type: application/json'
# 	-d '{"id": "4284942500502395006", "timestamp": [2023, 4, 10, 17, 53, 50, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:50", "date": "2023-04-10", "time": "17:53:50", "user": "afresco", "lat": 33.38, "lon": -96.79, "text": "Fudgemart just is.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2308695730795076510 -H 'Content-Type: application/json'
# 	-d '{"id": "2308695730795076510", "timestamp": [2023, 4, 10, 17, 53, 55, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:55", "date": "2023-04-10", "time": "17:53:55", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Techical support for my new computer as A+, thank you @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4414226014546991749 -H 'Content-Type: application/json'
# 	-d '{"id": "4414226014546991749", "timestamp": [2023, 4, 10, 17, 53, 57, 0, 100, 0], "timestamp_format": "2023-04-10T17:53:57", "date": "2023-04-10", "time": "17:53:57", "user": "gmoss", "lat": 41.38, "lon": -97.52, "text": "Happy with my service from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1034037398617159723 -H 'Content-Type: application/json'
# 	-d '{"id": "1034037398617159723", "timestamp": [2023, 4, 10, 17, 54, 0, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:00", "date": "2023-04-10", "time": "17:54:00", "user": "bdehatchett", "lat": 38.38, "lon": 87.76, "text": "I want to bash my head into the wall so difficult. @fudgemart", "sentiment": "negative", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/130460006146485018 -H 'Content-Type: application/json'
# 	-d '{"id": "130460006146485018", "timestamp": [2023, 4, 10, 17, 54, 4, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:04", "date": "2023-04-10", "time": "17:54:04", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Fudgemart's digital downloads is lacking titles!", "sentiment": "negative", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/517328483278409980 -H 'Content-Type: application/json'
# 	-d '{"id": "517328483278409980", "timestamp": [2023, 4, 10, 17, 54, 9, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:09", "date": "2023-04-10", "time": "17:54:09", "user": "lkarforless", "lat": 25.39, "lon": -108.54, "text": "You're the best @fudgemart! A+ shipping!", "sentiment": "positive", "mentions": ["@fudgemart!"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2772026809277274112 -H 'Content-Type: application/json'
# 	-d '{"id": "2772026809277274112", "timestamp": [2023, 4, 10, 17, 54, 11, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:11", "date": "2023-04-10", "time": "17:54:11", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Effective, Eloquent shopping! #fudgemart", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2226484490710216807 -H 'Content-Type: application/json'
# 	-d '{"id": "2226484490710216807", "timestamp": [2023, 4, 10, 17, 54, 12, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:12", "date": "2023-04-10", "time": "17:54:12", "user": "equittin", "lat": 35.38, "lon": -77.83, "text": "Happy with my service from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3085899219748388205 -H 'Content-Type: application/json'
# 	-d '{"id": "3085899219748388205", "timestamp": [2023, 4, 10, 17, 54, 14, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:14", "date": "2023-04-10", "time": "17:54:14", "user": "afresco", "lat": 33.38, "lon": -96.79, "text": "I Need more books, @fudgemart #encouraging.", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": ["#encouraging."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/284092962053602828 -H 'Content-Type: application/json'
# 	-d '{"id": "284092962053602828", "timestamp": [2023, 4, 10, 17, 54, 19, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:19", "date": "2023-04-10", "time": "17:54:19", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Shopping on #fudgemart website is carefree.", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1341676957100851004 -H 'Content-Type: application/json'
# 	-d '{"id": "1341676957100851004", "timestamp": [2023, 4, 10, 17, 54, 21, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:21", "date": "2023-04-10", "time": "17:54:21", "user": "bdehatchett", "lat": 38.38, "lon": 87.76, "text": "Yo, @fudgemart", "sentiment": "neutral", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1397803324098050343 -H 'Content-Type: application/json'
# 	-d '{"id": "1397803324098050343", "timestamp": [2023, 4, 10, 17, 54, 25, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:25", "date": "2023-04-10", "time": "17:54:25", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "How many books can you read? Fudgemart has a nice selection.", "sentiment": "positive", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4296970148475941807 -H 'Content-Type: application/json'
# 	-d '{"id": "4296970148475941807", "timestamp": [2023, 4, 10, 17, 54, 28, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:28", "date": "2023-04-10", "time": "17:54:28", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "I Need more books, @fudgemart #encouraging.", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": ["#encouraging."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4520815449056252112 -H 'Content-Type: application/json'
# 	-d '{"id": "4520815449056252112", "timestamp": [2023, 4, 10, 17, 54, 33, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:33", "date": "2023-04-10", "time": "17:54:33", "user": "sbeeches", "lat": 29.39, "lon": -99.68, "text": "Love or hate it. Fudgemart just is.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2171978626491587034 -H 'Content-Type: application/json'
# 	-d '{"id": "2171978626491587034", "timestamp": [2023, 4, 10, 17, 54, 35, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:35", "date": "2023-04-10", "time": "17:54:35", "user": "jtyme", "lat": 40.39, "lon": -74.83, "text": "Effective, Eloquent shopping! #fudgemart", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1184766742947825591 -H 'Content-Type: application/json'
# 	-d '{"id": "1184766742947825591", "timestamp": [2023, 4, 10, 17, 54, 39, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:39", "date": "2023-04-10", "time": "17:54:39", "user": "cpayne", "lat": 34.39, "lon": -83.74, "text": "Hey, @fudgemart. You've got products with benefits!", "sentiment": "positive", "mentions": ["@fudgemart."], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3835085190708284918 -H 'Content-Type: application/json'
# 	-d '{"id": "3835085190708284918", "timestamp": [2023, 4, 10, 17, 54, 41, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:41", "date": "2023-04-10", "time": "17:54:41", "user": "gtofwind", "lat": 34.38, "lon": -109.58, "text": "Fudgemart has a lot of Books available for purchase.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4079251361445343269 -H 'Content-Type: application/json'
# 	-d '{"id": "4079251361445343269", "timestamp": [2023, 4, 10, 17, 54, 45, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:45", "date": "2023-04-10", "time": "17:54:45", "user": "etasomthin", "lat": 43.38, "lon": -82.53, "text": "Fudgemart has a lot of Books available for purchase.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/926607287333020898 -H 'Content-Type: application/json'
# 	-d '{"id": "926607287333020898", "timestamp": [2023, 4, 10, 17, 54, 47, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:47", "date": "2023-04-10", "time": "17:54:47", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Glad I bought my electronics from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1205631040464617599 -H 'Content-Type: application/json'
# 	-d '{"id": "1205631040464617599", "timestamp": [2023, 4, 10, 17, 54, 52, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:52", "date": "2023-04-10", "time": "17:54:52", "user": "lkarforless", "lat": 25.39, "lon": -108.54, "text": "Effective, Eloquent shopping! #fudgemart", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3264283190653192068 -H 'Content-Type: application/json'
# 	-d '{"id": "3264283190653192068", "timestamp": [2023, 4, 10, 17, 54, 55, 0, 100, 0], "timestamp_format": "2023-04-10T17:54:55", "date": "2023-04-10", "time": "17:54:55", "user": "iquitten", "lat": 38.38, "lon": -95.51, "text": "I'm tired of being on the phone with electroincs support at @fudgemart", "sentiment": "negative", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1194079717772003321 -H 'Content-Type: application/json'
# 	-d '{"id": "1194079717772003321", "timestamp": [2023, 4, 10, 17, 55, 0, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:00", "date": "2023-04-10", "time": "17:55:00", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "Customer satisfaction through the roof right now.", "sentiment": "positive", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2407679648345978879 -H 'Content-Type: application/json'
# 	-d '{"id": "2407679648345978879", "timestamp": [2023, 4, 10, 17, 55, 1, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:01", "date": "2023-04-10", "time": "17:55:01", "user": "gtofwind", "lat": 34.38, "lon": -109.58, "text": "Who uses the fudgemart website", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1128807386458920848 -H 'Content-Type: application/json'
# 	-d '{"id": "1128807386458920848", "timestamp": [2023, 4, 10, 17, 55, 6, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:06", "date": "2023-04-10", "time": "17:55:06", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "I was very happy with my latest purchase from #fudgemart", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/468810849287417443 -H 'Content-Type: application/json'
# 	-d '{"id": "468810849287417443", "timestamp": [2023, 4, 10, 17, 55, 11, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:11", "date": "2023-04-10", "time": "17:55:11", "user": "lkarforless", "lat": 25.39, "lon": -108.54, "text": "Love or hate it. Fudgemart just is.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4528706728050467693 -H 'Content-Type: application/json'
# 	-d '{"id": "4528706728050467693", "timestamp": [2023, 4, 10, 17, 55, 14, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:14", "date": "2023-04-10", "time": "17:55:14", "user": "iquitten", "lat": 38.38, "lon": -95.51, "text": "How old are your clothes? Buy new ones at Fudgemart?", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2715835899861364349 -H 'Content-Type: application/json'
# 	-d '{"id": "2715835899861364349", "timestamp": [2023, 4, 10, 17, 55, 16, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:16", "date": "2023-04-10", "time": "17:55:16", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "I make my first order from fudgemart last week.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/129590363812442485 -H 'Content-Type: application/json'
# 	-d '{"id": "129590363812442485", "timestamp": [2023, 4, 10, 17, 55, 17, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:17", "date": "2023-04-10", "time": "17:55:17", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "Fudgemart's digital downloads: paltry!", "sentiment": "negative", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2391052818292654642 -H 'Content-Type: application/json'
# 	-d '{"id": "2391052818292654642", "timestamp": [2023, 4, 10, 17, 55, 20, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:20", "date": "2023-04-10", "time": "17:55:20", "user": "otyme", "lat": 30.39, "lon": -87.57, "text": "The books department at #fudgemart is amazing. Great support!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/112368734507096588 -H 'Content-Type: application/json'
# 	-d '{"id": "112368734507096588", "timestamp": [2023, 4, 10, 17, 55, 24, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:24", "date": "2023-04-10", "time": "17:55:24", "user": "iquitten", "lat": 38.38, "lon": -95.51, "text": "#fudgemart worse than #amazeen. #helpless.", "sentiment": "negative", "mentions": [], "hashtags": ["#fudgemart", "#amazeen.", "#helpless."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3618495540627170700 -H 'Content-Type: application/json'
# 	-d '{"id": "3618495540627170700", "timestamp": [2023, 4, 10, 17, 55, 28, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:28", "date": "2023-04-10", "time": "17:55:28", "user": "benarreau", "lat": 37.39, "lon": -85.74, "text": "The books department at #fudgemart is amazing. Great support!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1562623461235794583 -H 'Content-Type: application/json'
# 	-d '{"id": "1562623461235794583", "timestamp": [2023, 4, 10, 17, 55, 29, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:29", "date": "2023-04-10", "time": "17:55:29", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Just got some books from #fudgemart. Awesome!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3606551477493072540 -H 'Content-Type: application/json'
# 	-d '{"id": "3606551477493072540", "timestamp": [2023, 4, 10, 17, 55, 34, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:34", "date": "2023-04-10", "time": "17:55:34", "user": "iquitten", "lat": 38.38, "lon": -95.51, "text": "The Electronics department at #fudgemart is amazing. So helpful!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1575181481003051669 -H 'Content-Type: application/json'
# 	-d '{"id": "1575181481003051669", "timestamp": [2023, 4, 10, 17, 55, 37, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:37", "date": "2023-04-10", "time": "17:55:37", "user": "meyezing", "lat": 32.38, "lon": -92.7, "text": "likewise, @fudgemart", "sentiment": "neutral", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4040072257306302662 -H 'Content-Type: application/json'
# 	-d '{"id": "4040072257306302662", "timestamp": [2023, 4, 10, 17, 55, 38, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:38", "date": "2023-04-10", "time": "17:55:38", "user": "jtyme", "lat": 40.39, "lon": -74.83, "text": "I was very happy with my latest purchase from #fudgemart", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4526044413293190304 -H 'Content-Type: application/json'
# 	-d '{"id": "4526044413293190304", "timestamp": [2023, 4, 10, 17, 55, 43, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:43", "date": "2023-04-10", "time": "17:55:43", "user": "tpani", "lat": 27.38, "lon": -82.64, "text": "Glad I bought my books from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/31508466680039586 -H 'Content-Type: application/json'
# 	-d '{"id": "31508466680039586", "timestamp": [2023, 4, 10, 17, 55, 44, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:44", "date": "2023-04-10", "time": "17:55:44", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Do you enjoy books? Try @fudgemart.", "sentiment": "positive", "mentions": ["@fudgemart."], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4165895983568435393 -H 'Content-Type: application/json'
# 	-d '{"id": "4165895983568435393", "timestamp": [2023, 4, 10, 17, 55, 48, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:48", "date": "2023-04-10", "time": "17:55:48", "user": "sbellum", "lat": 36.39, "lon": -118.79, "text": "The Electronics department at #fudgemart is amazing. So helpful!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1738397040222995882 -H 'Content-Type: application/json'
# 	-d '{"id": "1738397040222995882", "timestamp": [2023, 4, 10, 17, 55, 49, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:49", "date": "2023-04-10", "time": "17:55:49", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "While I like their electronics, the books selection is lacking.", "sentiment": "negative", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4544701678161503772 -H 'Content-Type: application/json'
# 	-d '{"id": "4544701678161503772", "timestamp": [2023, 4, 10, 17, 55, 51, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:51", "date": "2023-04-10", "time": "17:55:51", "user": "tpani", "lat": 27.38, "lon": -82.64, "text": "Just got some books from #fudgemart. Awesome!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1499145095095984513 -H 'Content-Type: application/json'
# 	-d '{"id": "1499145095095984513", "timestamp": [2023, 4, 10, 17, 55, 53, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:53", "date": "2023-04-10", "time": "17:55:53", "user": "bitall", "lat": 41.39, "lon": -75.75, "text": "Love or hate it. Fudgemart just is.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4593702891824227172 -H 'Content-Type: application/json'
# 	-d '{"id": "4593702891824227172", "timestamp": [2023, 4, 10, 17, 55, 58, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:58", "date": "2023-04-10", "time": "17:55:58", "user": "sbellum", "lat": 36.39, "lon": -118.79, "text": "Fudgemart has a lot of Books available for purchase.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1099793091273238624 -H 'Content-Type: application/json'
# 	-d '{"id": "1099793091273238624", "timestamp": [2023, 4, 10, 17, 55, 59, 0, 100, 0], "timestamp_format": "2023-04-10T17:55:59", "date": "2023-04-10", "time": "17:55:59", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "How old are your clothes? Buy new ones at Fudgemart?", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2443971533993959080 -H 'Content-Type: application/json'
# 	-d '{"id": "2443971533993959080", "timestamp": [2023, 4, 10, 17, 56, 4, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:04", "date": "2023-04-10", "time": "17:56:04", "user": "cpayne", "lat": 34.39, "lon": -83.74, "text": "Shopping on #fudgemart website is carefree.", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1013499293536723165 -H 'Content-Type: application/json'
# 	-d '{"id": "1013499293536723165", "timestamp": [2023, 4, 10, 17, 56, 7, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:07", "date": "2023-04-10", "time": "17:56:07", "user": "gtofwind", "lat": 34.38, "lon": -109.58, "text": "Digital downloads selection on fudgemart is freakishly small. #bad", "sentiment": "negative", "mentions": [], "hashtags": ["#bad"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/712110117530188973 -H 'Content-Type: application/json'
# 	-d '{"id": "712110117530188973", "timestamp": [2023, 4, 10, 17, 56, 8, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:08", "date": "2023-04-10", "time": "17:56:08", "user": "gmoss", "lat": 41.38, "lon": -97.52, "text": "Just placed an order today. thx @fudgemart", "sentiment": "neutral", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/597753369191300395 -H 'Content-Type: application/json'
# 	-d '{"id": "597753369191300395", "timestamp": [2023, 4, 10, 17, 56, 12, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:12", "date": "2023-04-10", "time": "17:56:12", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "Digital downloads selection on fudgemart is freakishly small. #bad", "sentiment": "negative", "mentions": [], "hashtags": ["#bad"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1855011710752447305 -H 'Content-Type: application/json'
# 	-d '{"id": "1855011710752447305", "timestamp": [2023, 4, 10, 17, 56, 17, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:17", "date": "2023-04-10", "time": "17:56:17", "user": "afirenzergon", "lat": 41.38, "lon": -73.48, "text": "Just got some electronics from #fudgemart. Awesome!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart."]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/243401023323342715 -H 'Content-Type: application/json'
# 	-d '{"id": "243401023323342715", "timestamp": [2023, 4, 10, 17, 56, 19, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:19", "date": "2023-04-10", "time": "17:56:19", "user": "afresco", "lat": 33.38, "lon": -96.79, "text": "@fudgemart is better than @amazeen", "sentiment": "positive", "mentions": ["@fudgemart", "@amazeen"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1549634232535113849 -H 'Content-Type: application/json'
# 	-d '{"id": "1549634232535113849", "timestamp": [2023, 4, 10, 17, 56, 21, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:21", "date": "2023-04-10", "time": "17:56:21", "user": "tpani", "lat": 27.38, "lon": -82.64, "text": "Fudgemart just is.", "sentiment": "neutral", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/695003609042024165 -H 'Content-Type: application/json'
# 	-d '{"id": "695003609042024165", "timestamp": [2023, 4, 10, 17, 56, 23, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:23", "date": "2023-04-10", "time": "17:56:23", "user": "etasomthin", "lat": 43.38, "lon": -82.53, "text": "Fudgemart's digital downloads is lacking titles!", "sentiment": "negative", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4015176767052404486 -H 'Content-Type: application/json'
# 	-d '{"id": "4015176767052404486", "timestamp": [2023, 4, 10, 17, 56, 25, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:25", "date": "2023-04-10", "time": "17:56:25", "user": "tanott", "lat": 29.38, "lon": -94.84, "text": "Stellar experience at fudgemart. Kudos.", "sentiment": "positive", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1526590087859637740 -H 'Content-Type: application/json'
# 	-d '{"id": "1526590087859637740", "timestamp": [2023, 4, 10, 17, 56, 29, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:29", "date": "2023-04-10", "time": "17:56:29", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "The books department at #fudgemart is amazing. Great support!", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2123674857680109248 -H 'Content-Type: application/json'
# 	-d '{"id": "2123674857680109248", "timestamp": [2023, 4, 10, 17, 56, 32, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:32", "date": "2023-04-10", "time": "17:56:32", "user": "ojouglad", "lat": 33.39, "lon": -93.48, "text": "Do you enjoy #digital #downloads? Try @fudgemart.", "sentiment": "positive", "mentions": ["@fudgemart."], "hashtags": ["#digital", "#downloads?"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2195919437117382430 -H 'Content-Type: application/json'
# 	-d '{"id": "2195919437117382430", "timestamp": [2023, 4, 10, 17, 56, 35, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:35", "date": "2023-04-10", "time": "17:56:35", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "#fudgemart customer service is predictable", "sentiment": "neutral", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4600606896525151025 -H 'Content-Type: application/json'
# 	-d '{"id": "4600606896525151025", "timestamp": [2023, 4, 10, 17, 56, 36, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:36", "date": "2023-04-10", "time": "17:56:36", "user": "bitall", "lat": 41.39, "lon": -75.75, "text": "Very satisfying when your package arrives from #fudgemart", "sentiment": "positive", "mentions": [], "hashtags": ["#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/4280417133702444014 -H 'Content-Type: application/json'
# 	-d '{"id": "4280417133702444014", "timestamp": [2023, 4, 10, 17, 56, 41, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:41", "date": "2023-04-10", "time": "17:56:41", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "I hate the fudgemart books selection. Terrible.", "sentiment": "negative", "mentions": [], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/1337273779254536090 -H 'Content-Type: application/json'
# 	-d '{"id": "1337273779254536090", "timestamp": [2023, 4, 10, 17, 56, 42, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:42", "date": "2023-04-10", "time": "17:56:42", "user": "afirenzergon", "lat": 41.38, "lon": -73.48, "text": "The #books department at #fudgemart is amazing. Very helpful!", "sentiment": "positive", "mentions": [], "hashtags": ["#books", "#fudgemart"]}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/788607709050987190 -H 'Content-Type: application/json'
# 	-d '{"id": "788607709050987190", "timestamp": [2023, 4, 10, 17, 56, 43, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:43", "date": "2023-04-10", "time": "17:56:43", "user": "afresco", "lat": 33.38, "lon": -96.79, "text": "Happy with my service from @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/2651858689525093979 -H 'Content-Type: application/json'
# 	-d '{"id": "2651858689525093979", "timestamp": [2023, 4, 10, 17, 56, 47, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:47", "date": "2023-04-10", "time": "17:56:47", "user": "rdeboat", "lat": 33.39, "lon": -90.55, "text": "My shopping experience was delightful, @fudgemart", "sentiment": "positive", "mentions": ["@fudgemart"], "hashtags": []}'
# curl -X POST http://elasticsearch:9200/tweets/_doc/3967651883627049812 -H 'Content-Type: application/json'
# 	-d '{"id": "3967651883627049812", "timestamp": [2023, 4, 10, 17, 56, 52, 0, 100, 0], "timestamp_format": "2023-04-10T17:56:52", "date": "2023-04-10", "time": "17:56:52", "user": "edetyers", "lat": 38.39, "lon": -86.76, "text": "likewise, @fudgemart", "sentiment": "neutral", "mentions": ["@fudgemart"], "hashtags": []}'

# %% [markdown]
# ## Spark Elasticsearch
#
# The elasticsearch spark connector supports:
#
#  - Writing Spark  DataFrames to an ES index
#  - An entire ES index into a spark DataFrame
#  - It does NOT support ES Queries.
#  - It does not handle nested schemas without creating a customer mapping in elasticsearch

# %%
fm = spark.read.option("inferSchema",True).option("header",True).csv("file:///home/jovyan/datasets/fudgemart/fudgemart-order-details.csv")
fm.printSchema()

# %%
fm.show(5)

# %%
fm.write.mode("Overwrite").format("es").save("fm-order-details")

# %% [markdown]
# ### NOTE: Wait a minute for Elasticsearch to catch up!!!!
#
# - Don't read until the mapping is created.

# %%
fm2 = spark.read.format("es").load("fm-order-details")
fm2.show()

# %%
query = fm2.select("product_name","product_retail_price","order_qty").where("product_name='Steam Iron'")

# %%
query.explain()

# %%
# Filters are pushed down into elastic!!
fm2 = spark.read.format("es").load("fm-order-details")
fm2.where("customer_city='Fresno' and order_total<500").explain()

# %%
fm2.where("customer_city='Fresno' and order_total<500").toPandas()
